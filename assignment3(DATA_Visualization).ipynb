# %% [markdown]
# <a href="https://colab.research.google.com/github/clokesh315/data-visualization/blob/main/assignment3(DATA_Visualization).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/content/train-200907-141856.csv')
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(x='Survived', data = dataset)

# %%
sns.countplot(x='Survived', hue='Sex', data = dataset)

# %%
sns.lineplot(x='Age', y='Fare', data = dataset)

# %%
dataset.plot.scatter(x='Age', y='Fare')

# %%
dataset.plot.scatter(x='Age', y='Survived')

# %%
dataset['Age'].hist(bins=10)

# %%
sizes= dataset['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived', 'Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
